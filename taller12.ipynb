# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguaje Natural
#
# ## Taller #12: Análisis de sentimiento
# `Fecha de entrega: Mayo 27, 2021 (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %% [markdown]
# ###  `[25 pts]` Punto 1: Hacer análisis de sentimiento de los datos del anterior taller
# - Columna con el puntaje numérico del sentimiento
# - Pueden usar cualquiera de las librerias vistas en clase

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob

vader = SentimentIntensityAnalyzer()

# %%
import pandas as pd

data = pd.read_csv("D:/Maestria Analistica Estrategica de Datos/II semestre/NLP/taller11.csv")
data.head()
# Out:
#                                               tweets                 date  \
# 0  Hoy, Fémina Fútbol España presente en la celeb...  2021-05-20 01:12:21
# 1  ⏱️ El LIVERPOOL gana por goleada y asegura su ...  2021-05-20 00:38:28
# 2  ¡Pep Guardiola sigue agrandando su historia co...  2021-05-20 00:34:19
# 3  Liverpool ganó y depende de sí para clasificar...  2021-05-20 00:19:04
# 4  La Libertadores men. La puede ver en medio de ...  2021-05-20 00:17:01
#
#      city     user_location                   id  \
# 0  Bogotá               NaN  1395185595815714816
# 1  Bogotá    Cali, Colombia  1395177067919065089
# 2  Bogotá  Bogotá, Colombia  1395176020496588804
# 3  Bogotá  Bogotá, Colombia  1395172184029597699
# 4  Bogotá  Ibagué, Colombia  1395171666590945284
#
#                                                 link
# 0  https://twitter.com/i/web/stuatus/139518559581...
# 1  https://twitter.com/i/web/stuatus/139517706791...
# 2  https://twitter.com/i/web/stuatus/139517602049...
# ...

# %%
pd.set_option('display.max_colwidth', None)
data['sent_vader'] = data['tweets'].apply(lambda val: vader.polarity_scores(val)['compound'])
data['sent_textblob'] = data['tweets'].apply(lambda val: TextBlob(val).sentiment.polarity)
data[['tweets','sent_vader','sent_textblob']].head()
# Out:
#                                                                                                                                                                                                                                                                                  tweets  \
# 0                                                                                                            Hoy, Fémina Fútbol España presente en la celebración del Barcelona femenino💙❤️ \nCampeonas de la Liga Iberdrola y la Champions League.\n@FCBfemeni https://t.co/ynLsCabBHG
# 1                                                                                                                                             ⏱️ El LIVERPOOL gana por goleada y asegura su puesto en zona de CHAMPIONS LEAGUE frente al BURNLEY #PremierLeague https://t.co/84kZieDbs8
# ...

# %% [markdown]
# ###  `[25 pts]` Punto 2: ¿Cuál es el tuit más positivo y más negativo?

# %%
data[data['sent_vader']==data['sent_vader'].max()]
# Out:
#                                                                                                                                                                                                                                                                                  tweets  \
# 92  Especial: Champions 🏆⚽\n\nFinales de la Uefa Champions League entre equipos de un mismo país por @jesuscardonacantillo\n\nEntérate de #Champions en @enfodeportivo\n\nCuéntanos en los comentarios: \n\n¿Quién será el campeón de la UEFA Champions League? https://t.co/17jkp6OWa3
#
#                    date    city user_location                   id  \
# 92  2021-05-17 17:24:09  Bogotá      Colombia  1394342991276429314
#
#                                                      link  sent_vader  \
# 92  https://twitter.com/i/web/stuatus/1394342991276429314      0.9274
#
#     sent_textblob
# 92            0.0

# %%
data[data['sent_vader']==data['sent_vader'].min()]
# Out:
#                                                                                                                                                                                      tweets  \
# 61  @InvictosSomos Leicester no tiene absolutamente nada que hacer en Champions, hoy el partido era para que acabe 3-0, que el Tottenham mande a Europa League al Leicester sin problemas!!
#
#                    date    city user_location                   id  \
# 61  2021-05-18 21:17:42  Bogotá       ecuador  1394764155639500802
#
#                                                      link  sent_vader  \
# 61  https://twitter.com/i/web/stuatus/1394764155639500802     -0.4559
#
#     sent_textblob
# 61            0.0
